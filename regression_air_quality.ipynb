# %%
import torch
import pandas as pd

# %%
air_data = pd.read_csv('/Users/topih/Pytorch/datasets/AirQualityUCI/AirQualityUCI.csv', sep=';', engine='python')

# %%
air_data.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6         1360       150     11,9           1046
# 1  10/03/2004  19.00.00      2         1292       112      9,4            955
# 2  10/03/2004  20.00.00    2,2         1402        88      9,0            939
# 3  10/03/2004  21.00.00    2,2         1376        80      9,2            948
# 4  10/03/2004  22.00.00    1,6         1272        51      6,5            836
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0      166          1056      113          1692         1268  13,6  48,9
# 1      103          1174       92          1559          972  13,3  47,7
# 2      131          1140      114          1555         1074  11,9  54,0
# 3      172          1092      122          1584         1203  11,0  60,0
# 4      131          1205      116          1490         1110  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# 0  0,7578          NaN          NaN
# 1  0,7255          NaN          NaN
# 2  0,7502          NaN          NaN
# 3  0,7867          NaN          NaN
# 4  0,7888          NaN          NaN

# %%
unwanted_cols = ['Date', 'Time', 'PT08.S1(CO)', 'PT08.S2(NMHC)',
                'PT08.S3(NOx)', 'Unnamed: 15', 'Unnamed: 16']

# %%
air_data = air_data.drop(unwanted_cols, axis=1)

# %%
air_data.columns
# Out:
# Index(['CO(GT)', 'NMHC(GT)', 'C6H6(GT)', 'NOx(GT)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')

# %%
len(air_data)
# Out:
# 9357

# %%
~air_data.eq('-200').head(15)
# Out:
#     CO(GT)  NMHC(GT)  C6H6(GT)  NOx(GT)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0     True      True      True     True     True          True         True
# 1     True      True      True     True     True          True         True
# 2     True      True      True     True     True          True         True
# 3     True      True      True     True     True          True         True
# 4     True      True      True     True     True          True         True
# 5     True      True      True     True     True          True         True
# 6     True      True      True     True     True          True         True
# 7     True      True      True     True     True          True         True
# 8     True      True      True     True     True          True         True
# 9     True      True      True     True     True          True         True
# 10   False      True      True     True     True          True         True
# 11    True      True      True     True     True          True         True
# 12    True      True      True     True     True          True         True
# 13    True      True      True     True     True          True         True
# 14    True      True      True     True     True          True         True
#
#        T    RH    AH
# 0   True  True  True
# 1   True  True  True
# 2   True  True  True
# 3   True  True  True
# 4   True  True  True
# 5   True  True  True
# 6   True  True  True
# 7   True  True  True
# 8   True  True  True
# 9   True  True  True
# 10  True  True  True
# 11  True  True  True
# 12  True  True  True
# 13  True  True  True
# 14  True  True  True

# %%
~air_data.eq(-200).head(15)
# Out:
#     CO(GT)  NMHC(GT)  C6H6(GT)  NOx(GT)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0     True      True      True     True     True          True         True
# 1     True      True      True     True     True          True         True
# 2     True      True      True     True     True          True         True
# 3     True      True      True     True     True          True         True
# 4     True      True      True     True     True          True         True
# 5     True      True      True     True     True          True         True
# 6     True      True      True     True     True          True         True
# 7     True      True      True     True     True          True         True
# 8     True      True      True     True     True          True         True
# 9     True      True      True    False    False          True         True
# 10    True      True      True     True     True          True         True
# 11    True      True      True     True     True          True         True
# 12    True      True      True     True     True          True         True
# 13    True      True      True     True     True          True         True
# 14    True      True      True     True     True          True         True
#
#        T    RH    AH
# 0   True  True  True
# 1   True  True  True
# 2   True  True  True
# 3   True  True  True
# 4   True  True  True
# 5   True  True  True
# 6   True  True  True
# 7   True  True  True
# 8   True  True  True
# 9   True  True  True
# 10  True  True  True
# 11  True  True  True
# 12  True  True  True
# 13  True  True  True
# 14  True  True  True

# %%
air_data = air_data[~air_data.eq(-200)]
air_data = air_data[~air_data.eq('-200')]

# %%
air_data.head()
# Out:
#   CO(GT)  NMHC(GT) C6H6(GT)  NOx(GT)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0    2,6     150.0     11,9    166.0    113.0        1692.0       1268.0
# 1      2     112.0      9,4    103.0     92.0        1559.0        972.0
# 2    2,2      88.0      9,0    131.0    114.0        1555.0       1074.0
# 3    2,2      80.0      9,2    172.0    122.0        1584.0       1203.0
# 4    1,6      51.0      6,5    131.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13,6  48,9  0,7578
# 1  13,3  47,7  0,7255
# 2  11,9  54,0  0,7502
# 3  11,0  60,0  0,7867
# 4  11,2  59,6  0,7888

# %%
air_data = air_data.dropna()

# %%
len(air_data)
# Out:
# 827

# %%
air_data = air_data.apply(lambda x: pd.to_numeric(x.astype(str).str.replace(',','.')))
air_data.head()
# Out:
#    CO(GT)  NMHC(GT)  C6H6(GT)  NOx(GT)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0     2.6     150.0      11.9    166.0    113.0        1692.0       1268.0
# 1     2.0     112.0       9.4    103.0     92.0        1559.0        972.0
# 2     2.2      88.0       9.0    131.0    114.0        1555.0       1074.0
# 3     2.2      80.0       9.2    172.0    122.0        1584.0       1203.0
# 4     1.6      51.0       6.5    131.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888

# %%
air_data.dtypes
# Out:
# CO(GT)          float64
# NMHC(GT)        float64
# C6H6(GT)        float64
# NOx(GT)         float64
# NO2(GT)         float64
# PT08.S4(NO2)    float64
# PT08.S5(O3)     float64
# T               float64
# RH              float64
# AH              float64
# dtype: object

# %%
features = ['CO(GT)', 'NMHC(GT)', 'C6H6(GT)', 'NOx(GT)', 'NO2(GT)', 'T', 'RH', 'AH']
air_features = air_data[features]

# %%
air_features.head()
# Out:
#    CO(GT)  NMHC(GT)  C6H6(GT)  NOx(GT)  NO2(GT)     T    RH      AH
# 0     2.6     150.0      11.9    166.0    113.0  13.6  48.9  0.7578
# 1     2.0     112.0       9.4    103.0     92.0  13.3  47.7  0.7255
# 2     2.2      88.0       9.0    131.0    114.0  11.9  54.0  0.7502
# 3     2.2      80.0       9.2    172.0    122.0  11.0  60.0  0.7867
# 4     1.6      51.0       6.5    131.0    116.0  11.2  59.6  0.7888

# %%
air_target = air_data[['PT08.S5(O3)']]
air_target.head()
# Out:
#    PT08.S5(O3)
# 0       1268.0
# 1        972.0
# 2       1074.0
# 3       1203.0
# 4       1110.0

# %%
from sklearn import preprocessing

# %%
scalable_cols = air_features.columns

# %%
pd.options.mode.chained_assignment = None

# %%
air_features[scalable_cols] = preprocessing.scale(air_features[scalable_cols])

# %%
air_features.head()
# Out:
#      CO(GT)  NMHC(GT)  C6H6(GT)   NOx(GT)   NO2(GT)         T        RH  \
# 0  0.174943 -0.388917  0.152273  0.275105  0.404769 -0.415033 -0.009843
# 1 -0.250998 -0.571315 -0.184943 -0.495252 -0.262432 -0.477243 -0.088493
# 2 -0.109018 -0.686514 -0.238897 -0.152871  0.436541 -0.767556  0.324418
# 3 -0.109018 -0.724913 -0.211920  0.348473  0.690713 -0.954186  0.717667
# 4 -0.534959 -0.864111 -0.576113 -0.152871  0.500084 -0.912712  0.691451
#
#          AH
# 0 -0.415098
# 1 -0.596154
# 2 -0.457699
# 3 -0.253100
# 4 -0.241329

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, x_test, Y_train, y_test = train_test_split(air_features,
                                                   air_target,
                                                   test_size=0.05,
                                                   random_state=0)

# %%
dtype = torch.float

# %%
X_train_tensor = torch.tensor(X_train.values, dtype = dtype)
x_test_tensor = torch.tensor(x_test.values, dtype = dtype)

Y_train_tensor = torch.tensor(Y_train.values, dtype = dtype)
y_test_tensor = torch.tensor(y_test.values, dtype = dtype)

# %%
X_train_tensor.shape
# Out:
# torch.Size([785, 8])

# %%
Y_train_tensor.shape
# Out:
# torch.Size([785, 1])

# %%
inp = 8
out = 1
hid = 100
loss_fn = torch.nn.MSELoss()
learning_rate = 0.0001

# %%
model = torch.nn.Sequential(torch.nn.Linear(inp, hid),
                           torch.nn.Sigmoid(),
                           torch.nn.Linear(hid, out))

# %%
for iter in range(1, 100001):
    
    y_pred = model(X_train_tensor)
    loss = loss_fn(y_pred, Y_train_tensor)
    
    if iter % 10000 == 0:
        print(iter, int(loss.item()))
        
    model.zero_grad()
    loss.backward()
    
    with torch.no_grad():
        for param in model.parameters():
            param -= learning_rate * param.grad
# Out:
# 10000 8191
# 20000 6851
# 30000 6055
# 40000 5524
# 50000 5133
# 60000 4840
# 70000 4618
# 80000 4432
# 90000 4265
# 100000 4121

# %%
sample = x_test.iloc[23]
sample
# Out:
# CO(GT)     -0.250998
# NMHC(GT)   -0.206519
# C6H6(GT)   -0.117500
# NOx(GT)    -0.201782
# NO2(GT)     0.404769
# T           0.041172
# RH         -0.068830
# AH          0.140402
# Name: 532, dtype: float64

# %%
sample_tensor = torch.tensor(sample.values, dtype = dtype)
sample_tensor
# Out:
# tensor([-0.2510, -0.2065, -0.1175, -0.2018,  0.4048,  0.0412, -0.0688,  0.1404])

# %%
y_pred = model(sample_tensor)
print('Predicted air quality is : ', int(y_pred.item()))
print('Actual air quality is : ', int(y_test.iloc[23]))
# Out:
# Predicted air quality is :  1105
# Actual air quality is :  1200

# %%
y_pred_tensor = model(x_test_tensor)

# %%
y_pred = y_pred_tensor.detach().numpy()

# %%
import matplotlib.pyplot as plt

plt.scatter(y_pred, y_test.values)
plt.xlabel('Actual value')
plt.ylabel('Predicted value')

plt.title('Predicted value vs Actual value')
plt.show()

# %%
torch.save(model, 'my_model')

# %%
saved_model = torch.load('my_model')

# %%
y_pred_tensor = saved_model(x_test_tensor)

# %%
y_pred = y_pred_tensor.detach().numpy()

# %%
plt.figure(figsize=(15,6))
plt.plot(y_pred, label='Predicted value')
plt.plot(y_test.values, label='Actual value')
plt.legend()
plt.show()
